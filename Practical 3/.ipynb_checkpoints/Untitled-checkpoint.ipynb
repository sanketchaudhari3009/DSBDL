# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import pylab
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("nba.csv")

# %%
df.isna().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
df['Weight']=df['Weight'].fillna(df['Weight'].mean())

# %%
df['Number']=df['Number'].fillna(df['Number'].mode())

# %%
df['Salary']=df['Salary'].fillna(df['Salary'].quantile(0.5)) #similar to median()

# %%
df.isna().sum()
# Out:
# Name         1
# Team         1
# Number       0
# Position     1
# Age          1
# Height       1
# Weight       0
# College     85
# Salary       0
# dtype: int64

# %%
df.dtypes
# Out:
# Name         object
# Team         object
# Number      float64
# Position     object
# Age         float64
# Height       object
# Weight      float64
# College      object
# Salary      float64
# dtype: object

# %%
alpha=df.select_dtypes(include='object')

# %%
alpha.isna().sum()
# Out:
# Name         1
# Team         1
# Position     1
# Height       1
# College     85
# dtype: int64

# %%
alpha.dropna(subset=['College'], axis = 0, inplace=True)

# %%
alpha.isna().sum()
# Out:
# Name        0
# Team        0
# Position    0
# Height      0
# College     0
# dtype: int64

# %%
#data transformation scaling for change
#minmax
numeric=df.select_dtypes(include=np.number)

# %%
for i in numeric.columns:
    numeric[i]=(numeric[i]-numeric[i].min())/(numeric[i].max()-numeric[i].min())
numeric
# Out:
#        Number       Age    Weight    Salary
# 0    0.000000  0.285714  0.130137  0.308359
# 1    1.000000  0.285714  0.506849  0.270944
# 2    0.303030  0.380952  0.301370  0.112466
# 3    0.282828  0.142857  0.164384  0.044765
# 4    0.080808  0.476190  0.479452  0.199010
# ..        ...       ...       ...       ...
# 453  0.080808  0.333333  0.287671  0.096217
# 454  0.252525  0.238095  0.123288  0.034807
# 455  0.212121  0.333333  0.650685  0.114906
# 456  0.242424  0.333333  0.479452  0.036701
# 457  0.178569       NaN  0.414541  0.112466
#
# [458 rows x 4 columns]

# %%
numeric.plot(kind='bar')
# Out:
# <Axes: >

# %%
numeric.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
numeric.plot(kind='box')
# Out:
# <Axes: >

# %%
zs=df.select_dtypes(include=np.number)

# %%
for i in zs.columns:
    zs[i]=(zs[i]-zs[i].mean())/zs[i].std()

# %%
zs.plot(kind='bar')
zs.plot(kind='box')
zs.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
zs.skew()
# Out:
# Number    1.670199
# Age       0.626349
# Weight    0.113912
# Salary    1.617114
# dtype: float64

# %%
zs.mean()
# Out:
# Number    8.144868e-17
# Age      -2.254457e-16
# Weight    6.787390e-17
# Salary   -2.666475e-17
# dtype: float64

# %%
sns.distplot(zs['Weight'])
# Out:
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
df['Weight2']=np.exp(df['Weight']) #use log, exp, sqrt, 1/(df['Weight'])

# %%
def normality(data, feature):
    plt.figure(figsize=(10,5))
    plt.subplot(1,2,1)
    sns.kdeplot(data[feature])
    plt.subplot(1,2,2)
    stats.probplot(data[feature],plot=pylab)
    plt.show()
normality(df,'Weight2')
