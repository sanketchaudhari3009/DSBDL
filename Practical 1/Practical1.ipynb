# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing

# %%
df = pd.read_csv('Placement_Data_Full_Class.csv')

# %%
df.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
for i in df:
    if(df[i].dtypes == "float64"):
        df[i] = df[i].fillna(df[i].mean())

# %%
df.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
df.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
df
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  \
# ...

# %%
labelencoder=preprocessing.LabelEncoder()

# %%
for i in df:
    if df[i].dtypes=="object":
        df[i]=labelencoder.fit_transform(df[i])

# %%
df
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0        1       1  67.00      1  91.00      1      1     58.00         2
# 1        2       1  79.33      0  78.33      1      2     77.48         2
# 2        3       1  65.00      0  68.00      0      0     64.00         0
# 3        4       1  56.00      0  52.00      0      2     52.00         2
# 4        5       1  85.80      0  73.60      0      1     73.30         0
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210    211       1  80.60      1  82.00      1      1     77.60         0
# 211    212       1  58.00      1  60.00      1      2     72.00         2
# 212    213       1  67.00      1  67.00      1      1     73.00         0
# 213    214       0  74.00      1  66.00      1      1     58.00         0
# 214    215       1  62.00      0  58.00      1      2     53.00         0
#
#      workex  etest_p  specialisation  mba_p  status         salary
# ...

# %%
dfhot = pd.read_csv('Placement_Data_Full_Class.csv')

# %%
# !pip install one_hot_encoder

# %%
onehotencoder=preprocessing.OneHotEncoder()

# %%
encoded_df = pd.get_dummies(dfhot)

for column in encoded_df:
    if(encoded_df[column].dtypes=="object"):
        encoded_df[column] = pd.DataFrame(onehotencoder.fit_transform(encoded_df[[column]]).toarray())

# %%
encoded_df
# Out:
#      sl_no  ssc_p  hsc_p  degree_p  etest_p  mba_p    salary  gender_F  \
# 0        1  67.00  91.00     58.00     55.0  58.80  270000.0     False
# 1        2  79.33  78.33     77.48     86.5  66.28  200000.0     False
# 2        3  65.00  68.00     64.00     75.0  57.80  250000.0     False
# 3        4  56.00  52.00     52.00     66.0  59.43       NaN     False
# 4        5  85.80  73.60     73.30     96.8  55.50  425000.0     False
# ..     ...    ...    ...       ...      ...    ...       ...       ...
# 210    211  80.60  82.00     77.60     91.0  74.49  400000.0     False
# 211    212  58.00  60.00     72.00     74.0  53.62  275000.0     False
# 212    213  67.00  67.00     73.00     59.0  69.72  295000.0     False
# 213    214  74.00  66.00     58.00     70.0  60.23  204000.0      True
# 214    215  62.00  58.00     53.00     89.0  60.22       NaN     False
#
#      gender_M  ssc_b_Central  ...  hsc_s_Science  degree_t_Comm&Mgmt  \
# ...

# %%
df2 = pd.read_csv('Placement_Data_Full_Class.csv')

# %%
df2.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
for i in df2:
    if(df2[i].dtypes=='float64'):
        df2[i]=df2[i].fillna(df2[i].mean())

# %%
change_dt={'salary':int}
df2=df2.astype(change_dt)

# %%
df2.isna().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
df2
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
df2['hsc_b'] = df2['hsc_b'].astype(str)

# %%
df2['hsc_b']=df2['hsc_b'].str.lower()

# %%
df2
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   others   Science     77.48
# 2        3      M  65.00  Central  68.00  central      Arts     64.00
# 3        4      M  56.00  Central  52.00  central   Science     52.00
# 4        5      M  85.80  Central  73.60  central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   others   Science     72.00
# 212    213      M  67.00   Others  67.00   others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status  salary
# ...

# %%
df2['hsc_b']=df2['hsc_b'].str.replace(' ','')

# %%
df2['hsc_b']=df2['hsc_b'].str.lstrip()
df2['hsc_b']=df2['hsc_b'].str.rstrip()

# %%
df
# Out:
#      sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# 0        1       1  67.00      1  91.00      1      1     58.00         2
# 1        2       1  79.33      0  78.33      1      2     77.48         2
# 2        3       1  65.00      0  68.00      0      0     64.00         0
# 3        4       1  56.00      0  52.00      0      2     52.00         2
# 4        5       1  85.80      0  73.60      0      1     73.30         0
# ..     ...     ...    ...    ...    ...    ...    ...       ...       ...
# 210    211       1  80.60      1  82.00      1      1     77.60         0
# 211    212       1  58.00      1  60.00      1      2     72.00         2
# 212    213       1  67.00      1  67.00      1      1     73.00         0
# 213    214       0  74.00      1  66.00      1      1     58.00         0
# 214    215       1  62.00      0  58.00      1      2     53.00         0
#
#      workex  etest_p  specialisation  mba_p  status         salary
# ...

# %%
scaler=preprocessing.MinMaxScaler()

# %%
columns=[]
for i in df:
    columns.append(i)
columns
# Out:
# ['sl_no',
#  'gender',
#  'ssc_p',
#  'ssc_b',
#  'hsc_p',
#  'hsc_b',
#  'hsc_s',
#  'degree_p',
#  'degree_t',
#  'workex',
#  'etest_p',
#  'specialisation',
#  'mba_p',
#  'status',
#  'salary']

# %%
df=scaler.fit_transform(df)
df=pd.DataFrame(df, columns=columns)

# %%
df
# Out:
#         sl_no  gender     ssc_p  ssc_b     hsc_p  hsc_b  hsc_s  degree_p  \
# 0    0.000000     1.0  0.538240    1.0  0.889621    1.0    0.5  0.195122
# 1    0.004673     1.0  0.792414    0.0  0.680890    1.0    1.0  0.670244
# 2    0.009346     1.0  0.497011    0.0  0.510708    0.0    0.0  0.341463
# 3    0.014019     1.0  0.311482    0.0  0.247117    0.0    1.0  0.048780
# 4    0.018692     1.0  0.925788    0.0  0.602965    0.0    0.5  0.568293
# ..        ...     ...       ...    ...       ...    ...    ...       ...
# 210  0.981308     1.0  0.818594    1.0  0.741351    1.0    0.5  0.673171
# 211  0.985981     1.0  0.352711    1.0  0.378913    1.0    1.0  0.536585
# 212  0.990654     1.0  0.538240    1.0  0.494234    1.0    0.5  0.560976
# 213  0.995327     0.0  0.682540    1.0  0.477759    1.0    0.5  0.195122
# 214  1.000000     1.0  0.435168    0.0  0.345964    1.0    1.0  0.073171
#
#      degree_t  workex   etest_p  specialisation     mba_p  status    salary
# ...

# %%
#formula minmax
number=df.select_dtypes(include=np.number)

# %%
numberdf = number.copy()

# %%
numberdf
# Out:
#         sl_no  gender     ssc_p  ssc_b     hsc_p  hsc_b  hsc_s  degree_p  \
# 0    0.000000     1.0  0.538240    1.0  0.889621    1.0    0.5  0.195122
# 1    0.004673     1.0  0.792414    0.0  0.680890    1.0    1.0  0.670244
# 2    0.009346     1.0  0.497011    0.0  0.510708    0.0    0.0  0.341463
# 3    0.014019     1.0  0.311482    0.0  0.247117    0.0    1.0  0.048780
# 4    0.018692     1.0  0.925788    0.0  0.602965    0.0    0.5  0.568293
# ..        ...     ...       ...    ...       ...    ...    ...       ...
# 210  0.981308     1.0  0.818594    1.0  0.741351    1.0    0.5  0.673171
# 211  0.985981     1.0  0.352711    1.0  0.378913    1.0    1.0  0.536585
# 212  0.990654     1.0  0.538240    1.0  0.494234    1.0    0.5  0.560976
# 213  0.995327     0.0  0.682540    1.0  0.477759    1.0    0.5  0.195122
# 214  1.000000     1.0  0.435168    0.0  0.345964    1.0    1.0  0.073171
#
#      degree_t  workex   etest_p  specialisation     mba_p  status    salary
# ...

# %%
for i in numberdf.columns:
    numberdf[i] = (numberdf[i]-numberdf[i].min())/(numberdf[i].max()-numberdf[i].min())

# %%
numberdf
# Out:
#         sl_no  gender     ssc_p  ssc_b     hsc_p  hsc_b  hsc_s  degree_p  \
# 0    0.000000     1.0  0.538240    1.0  0.889621    1.0    0.5  0.195122
# 1    0.004673     1.0  0.792414    0.0  0.680890    1.0    1.0  0.670244
# 2    0.009346     1.0  0.497011    0.0  0.510708    0.0    0.0  0.341463
# 3    0.014019     1.0  0.311482    0.0  0.247117    0.0    1.0  0.048780
# 4    0.018692     1.0  0.925788    0.0  0.602965    0.0    0.5  0.568293
# ..        ...     ...       ...    ...       ...    ...    ...       ...
# 210  0.981308     1.0  0.818594    1.0  0.741351    1.0    0.5  0.673171
# 211  0.985981     1.0  0.352711    1.0  0.378913    1.0    1.0  0.536585
# 212  0.990654     1.0  0.538240    1.0  0.494234    1.0    0.5  0.560976
# 213  0.995327     0.0  0.682540    1.0  0.477759    1.0    0.5  0.195122
# 214  1.000000     1.0  0.435168    0.0  0.345964    1.0    1.0  0.073171
#
#      degree_t  workex   etest_p  specialisation     mba_p  status    salary
# ...

# %%
#zscore

# %%
scaler=preprocessing.StandardScaler()

# %%
numberdf[i]=scaler.fit_transform(numberdf)

# %%
numberdf=pd.DataFrame(numberdf,columns=columns)

# %%
numberdf
# Out:
#         sl_no  gender     ssc_p  ssc_b     hsc_p  hsc_b  hsc_s  degree_p  \
# 0    0.000000     1.0  0.538240    1.0  0.889621    1.0    0.5  0.195122
# 1    0.004673     1.0  0.792414    0.0  0.680890    1.0    1.0  0.670244
# 2    0.009346     1.0  0.497011    0.0  0.510708    0.0    0.0  0.341463
# 3    0.014019     1.0  0.311482    0.0  0.247117    0.0    1.0  0.048780
# 4    0.018692     1.0  0.925788    0.0  0.602965    0.0    0.5  0.568293
# ..        ...     ...       ...    ...       ...    ...    ...       ...
# 210  0.981308     1.0  0.818594    1.0  0.741351    1.0    0.5  0.673171
# 211  0.985981     1.0  0.352711    1.0  0.378913    1.0    1.0  0.536585
# 212  0.990654     1.0  0.538240    1.0  0.494234    1.0    0.5  0.560976
# 213  0.995327     0.0  0.682540    1.0  0.477759    1.0    0.5  0.195122
# 214  1.000000     1.0  0.435168    0.0  0.345964    1.0    1.0  0.073171
#
#      degree_t  workex   etest_p  specialisation     mba_p  status    salary
# ...

# %%
#formula
for i in numberdf.columns:
    numberdf[i]=(numberdf[i]-numberdf[i].mean())/numberdf[i].std()
